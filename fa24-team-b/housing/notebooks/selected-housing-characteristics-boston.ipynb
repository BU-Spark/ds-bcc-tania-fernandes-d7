# %% [markdown]
# ### Selected Housing Characteristics for Boston vs. District 7

# %% [markdown]
# #### Importing the datasets for Boston City as a whole

# %%
import pandas as pd

df_2011 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2011.DP04-Data.csv")
df_2012 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2012.DP04-Data.csv")
df_2013 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2013.DP04-Data.csv")
df_2014 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2014.DP04-Data.csv")
df_2015 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2015.DP04-Data.csv")
df_2016 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2016.DP04-Data.csv")
df_2017 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2017.DP04-Data.csv")
df_2018 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2018.DP04-Data.csv")
df_2019 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2019.DP04-Data.csv")
df_2020 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2020.DP04-Data.csv")
df_2021 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2021.DP04-Data.csv")
df_2022 = pd.read_csv(r"..\data\selected_housing_characteristics\boston\ACSDP5Y2022.DP04-Data.csv")

# %% [markdown]
# #### Importing the datasets for District 7

# %%
df_2011_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2011.DP04-Data.csv")
df_2012_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2012.DP04-Data.csv")
df_2013_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2013.DP04-Data.csv")
df_2014_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2014.DP04-Data.csv")
df_2015_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2015.DP04-Data.csv")
df_2016_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2016.DP04-Data.csv")
df_2017_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2017.DP04-Data.csv")
df_2018_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2018.DP04-Data.csv")
df_2019_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2019.DP04-Data.csv")
df_2020_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2020.DP04-Data.csv")
df_2021_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2021.DP04-Data.csv")
df_2022_d7 = pd.read_csv(r"..\data\selected_housing_characteristics\d7\ACSDP5Y2022.DP04-Data.csv")

# %%
df_2011.head()
# Out:
#              GEO_ID                        NAME  \
# 0         Geography        Geographic Area Name
# 1  1600000US2507000  Boston city, Massachusetts
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                            272007
#
#                                           DP04_0001M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                               1461
#
#                                        DP04_0001PE  \
# 0  Percent!!HOUSING OCCUPANCY!!Total housing units
# 1                                           272007
#
#                                          DP04_0001PM  \
# 0  Percent Margin of Error!!HOUSING OCCUPANCY!!To...
# 1                                                (X)
#
#                                           DP04_0002E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Occupied housing ...
# 1                                             247621
#
# ...

# %%
df_2011_d7.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0             Geography                               Geographic Area Name
# 1  1400000US25025010300    Census Tract 103, Suffolk County, Massachusetts
# 2  1400000US25025010403  Census Tract 104.03, Suffolk County, Massachus...
# 3  1400000US25025010404  Census Tract 104.04, Suffolk County, Massachus...
# 4  1400000US25025010405  Census Tract 104.05, Suffolk County, Massachus...
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                               279
# 2                                              2074
# 3                                              1859
# 4                                              1030
#
#                                           DP04_0001M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                                 49
# ...

# %%
# List of dataframes
dataframes = [df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022]

# Function to replace column headers with the first row
def replace_headers(df):
    df.columns = df.iloc[0]  # Set the first row as the header
    df = df.drop(index=0)  # Drop the first row
    df.reset_index(drop=True, inplace=True)  # Reset the index
    return df

df_2011 = replace_headers(df_2011)
df_2012 = replace_headers(df_2012)
df_2013 = replace_headers(df_2013)
df_2014 = replace_headers(df_2014)
df_2015 = replace_headers(df_2015)
df_2016 = replace_headers(df_2016)
df_2017 = replace_headers(df_2017)
df_2018 = replace_headers(df_2018)
df_2019 = replace_headers(df_2019)
df_2020 = replace_headers(df_2020)
df_2021 = replace_headers(df_2021)
df_2022 = replace_headers(df_2022)

# %%
def remove_margin_of_error_columns(df):
    # Identify columns to drop
    columns_to_drop = df.filter(like='Margin of Error').columns
    columns_to_drop2 = df.filter(like='Percent').columns
    
    # Only drop columns that exist in the DataFrame
    df = df.drop(columns=[col for col in columns_to_drop if col in df.columns])
    df = df.drop(columns=[col for col in columns_to_drop2 if col in df.columns])
    
    return df

# %%
df_2011
# Out:
# 0         Geography        Geographic Area Name  \
# 0  1600000US2507000  Boston city, Massachusetts
#
# 0 Estimate!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                           272007
#
# 0 Margin of Error!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                               1461
#
# 0 Percent!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                          272007
#
# 0 Percent Margin of Error!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                                (X)
#
# 0 Estimate!!HOUSING OCCUPANCY!!Occupied housing units  \
# 0                                             247621
#
# 0 Margin of Error!!HOUSING OCCUPANCY!!Occupied housing units  \
# 0                                               1938
#
# 0 Percent!!HOUSING OCCUPANCY!!Occupied housing units  \
# 0                                               91.0
#
# ...

# %%
df_2022
# Out:
# 0         Geography        Geographic Area Name  \
# 0  1600000US2507000  Boston city, Massachusetts
#
# 0 Estimate!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                           304079
#
# 0 Margin of Error!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                                895
#
# 0 Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units  \
# 0                                             276053
#
# 0 Margin of Error!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units  \
# 0                                               1667
#
# 0 Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units  \
# 0                                              28026
#
# 0 Margin of Error!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units  \
# 0                                               1438
#
# 0 Estimate!!HOUSING OCCUPANCY!!Total housing units!!Homeowner vacancy rate  \
# ...

# %% [markdown]
# #### Renaming the columns for easier readability and understanding

# %%
def rename_columns(df):
    # Define the column renaming mapping
    column_mapping = {
        'Estimate!!HOUSING OCCUPANCY!!Total housing units': 'Total Housing Units',
        'Estimate!!HOUSING OCCUPANCY!!Occupied housing units': 'Occupied Housing Units',
        'Estimate!!HOUSING OCCUPANCY!!Vacant housing units': 'Vacant Housing Units',
        'Estimate!!UNITS IN STRUCTURE!!Total housing units' : "Total Housing Units",
        'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units' : 'Occupied Housing Units',
        'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units' : 'Vacant Housing Units',
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!1-unit, detached' : "1-unit, detached",
        'Estimate!!UNITS IN STRUCTURE!!1-unit, detached': "1-unit, detached",
        'Estimate!!UNITS IN STRUCTURE!!1-unit, attached': "1-unit, attached",
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!1-unit, attached' : "1-unit, attached",
        'Estimate!!UNITS IN STRUCTURE!!2 units' : "2 units",
        'Estimate!!UNITS IN STRUCTURE!!3 or 4 units' : "3-4 units",
        'Estimate!!UNITS IN STRUCTURE!!5 to 9 units' : '5-9 units',
        'Estimate!!UNITS IN STRUCTURE!!10 to 19 units' : '10-19 units',
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!2 units' : "2 units",
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!3 or 4 units' : "3-4 units",
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!5 to 9 units' : "5-9 units",
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!10 to 19 units' : '10-19 units',
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!20 or more units' : '20+ units',
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!Mobile home' : 'Mobile Home',
        'Estimate!!UNITS IN STRUCTURE!!Total housing units!!Boat, RV, van, etc.' : 'Boat, RV, Van, etc.',
        'Estimate!!ROOMS!!Total housing units!!1 room' : '1 room',
        'Estimate!!ROOMS!!Total housing units!!2 rooms' : '2 rooms',
        'Estimate!!ROOMS!!Total housing units!!3 rooms' : '3 rooms',
        'Estimate!!ROOMS!!Total housing units!!4 rooms' : '4 rooms',
        'Estimate!!ROOMS!!Total housing units!!5 rooms' : '5 rooms',
        'Estimate!!ROOMS!!Total housing units!!6 rooms' : '6 rooms',
        'Estimate!!ROOMS!!Total housing units!!7 rooms' : '7 rooms',
        'Estimate!!ROOMS!!Total housing units!!8 rooms' : '8 rooms',
        'Estimate!!ROOMS!!Total housing units!!9 rooms or more' : '9+ rooms',
        'Estimate!!ROOMS!!Total housing units!!Median rooms' : 'Median Rooms',
        'Estimate!!BEDROOMS!!Total housing units!!No bedroom' : 'No Bedrooms',
        'Estimate!!BEDROOMS!!Total housing units!!1 bedroom' : '1 Bedroom',
        'Estimate!!BEDROOMS!!Total housing units!!2 bedrooms' : '2 Bedrooms',
        'Estimate!!BEDROOMS!!Total housing units!!3 bedrooms' : '3 Bedrooms',
        'Estimate!!BEDROOMS!!Total housing units!!4 bedrooms' : '4 Bedrooms',
        'Estimate!!BEDROOMS!!Total housing units!!5 or more bedrooms' : '5+ Bedrooms',
        'Estimate!!HOUSING TENURE!!Occupied housing units!!Owner-occupied' : "Owner Occupied",
        'Estimate!!HOUSING TENURE!!Occupied housing units!!Renter-occupied' : "Renter Occupied",
        'Estimate!!HOUSING TENURE!!Occupied housing units!!Average household size of owner-occupied unit' : "Avg Household Size - Owner Occupied",
        'Estimate!!HOUSING TENURE!!Occupied housing units!!Average household size of renter-occupied unit' : "Avg Household Size - Renter Occupied",
        'Estimate!!VALUE!!Owner-occupied units!!Less than $50,000' : '< $50,000',
        'Estimate!!VALUE!!Owner-occupied units!!$50,000 to $99,999' : '$50,000 - $99,999',
        'Estimate!!VALUE!!Owner-occupied units!!$100,000 to $149,999' : '$100,000 - $149,999',
        'Estimate!!VALUE!!Owner-occupied units!!$150,000 to $199,999' : '$150,000 to $199,999',
        'Estimate!!VALUE!!Owner-occupied units!!$200,000 to $299,999' : '$200,000 to $299,999',
        'Estimate!!VALUE!!Owner-occupied units!!$300,000 to $499,999' : '$300,000 to $499,999',
        'Estimate!!VALUE!!Owner-occupied units!!$500,000 to $999,999' : "$500,000 to $999,999",
        'Estimate!!VALUE!!Owner-occupied units!!$1,000,000 or more' : "$1,000,000 or more",
        'Estimate!!VALUE!!Owner-occupied units!!Median (dollars)' : "Median (dollars)",
        'Estimate!!GROSS RENT!!Occupied units paying rent' : "Occupied Units Paying Rent",
        'Estimate!!GROSS RENT!!Occupied units paying rent!!Less than $500' : "Rent: < $500",
        'Estimate!!GROSS RENT!!Less than $200' : "Rent: < $200",
        'Estimate!!GROSS RENT!!$500 to $999' : "Rent: $500 - $999",
        'Estimate!!GROSS RENT!!$1,000 to $1,499' : "Rent: $1,000 - $1,499",
        'Estimate!!GROSS RENT!!$1,500 to $1,999' : "Rent: $1,500 - $1,999",
        'Estimate!!GROSS RENT!!$2,000 to $2,499' : "Rent: $2,000 - $2,499", 
        'Estimate!!GROSS RENT!!$2,500 to $2,999' : "Rent: $2,500 - $2,999", 
        'Estimate!!GROSS RENT!!$3,000 or more' : "Rent: $3,000+", 
        'Estimate!!GROSS RENT!!Median (dollars)' : "Median Rent($)", 
        'Estimate!!GROSS RENT!!No rent paid' : "No Rent Paid",
        'Estimate!!GROSS RENT!!$500 to $999' : "Rent: $500 - $999",
        'Estimate!!GROSS RENT!!$1,000 to $1,499' : "Rent: $1,000 - $1,499",
        'Estimate!!GROSS RENT!!$1,500 to $1,999' : "Rent: $1,500 - $1,999",
        'Estimate!!GROSS RENT!!$2,000 to $2,499' : "Rent: $2,000 - $2,499", 
        'Estimate!!GROSS RENT!!$2,500 to $2,999' : "Rent: $2,500 - $2,999", 
        'Estimate!!GROSS RENT!!$3,000 or more' : "Rent: $3,000+", 
        'Estimate!!GROSS RENT!!Median (dollars)' : "Median Rent($)", 
        'Estimate!!GROSS RENT!!No rent paid' : "No Rent Paid",
        'Estimate!!GROSS RENT!!Occupied units paying rent!!$500 to $999' : "Rent: $500 - $999",
       'Estimate!!GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499' : "Rent: $1,000 - $1,499",
       'Estimate!!GROSS RENT!!Occupied units paying rent!!$1,500 to $1,999' : "Rent: $1,500 - $1,999",
       'Estimate!!GROSS RENT!!Occupied units paying rent!!$2,000 to $2,499' : "Rent: $2,000 - $2,499", 
       'Estimate!!GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999' : "Rent: $2,500 - $2,999", 
         'Estimate!!GROSS RENT!!Occupied units paying rent!!$3,000 or more' : "Rent: $3,000+", 
       'Estimate!!GROSS RENT!!Occupied units paying rent!!Median (dollars)' : "Median Rent($)", 
           'Estimate!!GROSS RENT!!Occupied units paying rent!!No rent paid' : "No Rent Paid",
        
    }
    
    # Rename the columns
    df = df.rename(columns=column_mapping)
    
    return df

# Apply the rename_columns function to each dataset
df_2011 = rename_columns(df_2011)
df_2012 = rename_columns(df_2012)
df_2013 = rename_columns(df_2013)
df_2014 = rename_columns(df_2014)
df_2015 = rename_columns(df_2015)
df_2016 = rename_columns(df_2016)
df_2017 = rename_columns(df_2017)
df_2018 = rename_columns(df_2018)
df_2019 = rename_columns(df_2019)
df_2020 = rename_columns(df_2020)
df_2021 = rename_columns(df_2021)
df_2022 = rename_columns(df_2022)

# %%
df_2011
# Out:
# 0         Geography        Geographic Area Name Total Housing Units  \
# 0  1600000US2507000  Boston city, Massachusetts              272007
#
# 0 Margin of Error!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                               1461
#
# 0 Percent!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                          272007
#
# 0 Percent Margin of Error!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                                (X)
#
# 0 Occupied Housing Units  \
# 0                 247621
#
# 0 Margin of Error!!HOUSING OCCUPANCY!!Occupied housing units  \
# 0                                               1938
#
# 0 Percent!!HOUSING OCCUPANCY!!Occupied housing units  \
# 0                                               91.0
#
# 0 Percent Margin of Error!!HOUSING OCCUPANCY!!Occupied housing units  ...  \
# 0                                                0.5                  ...
#
# ...

# %%
df_2011_d7 = replace_headers(df_2011_d7)
df_2012_d7 = replace_headers(df_2012_d7)
df_2013_d7 = replace_headers(df_2013_d7)
df_2014_d7 = replace_headers(df_2014_d7)
df_2015_d7 = replace_headers(df_2015_d7)
df_2016_d7 = replace_headers(df_2016_d7)
df_2017_d7 = replace_headers(df_2017_d7)
df_2018_d7 = replace_headers(df_2018_d7)
df_2019_d7 = replace_headers(df_2019_d7)
df_2020_d7 = replace_headers(df_2020_d7)
df_2021_d7 = replace_headers(df_2021_d7)
df_2022_d7 = replace_headers(df_2022_d7)

df_2011_d7 = remove_margin_of_error_columns(df_2011_d7)
df_2012_d7 = remove_margin_of_error_columns(df_2012_d7)
df_2013_d7 = remove_margin_of_error_columns(df_2013_d7)
df_2014_d7 = remove_margin_of_error_columns(df_2014_d7)
df_2015_d7 = remove_margin_of_error_columns(df_2015_d7)
df_2016_d7 = remove_margin_of_error_columns(df_2016_d7)
df_2017_d7 = remove_margin_of_error_columns(df_2017_d7)
df_2018_d7 = remove_margin_of_error_columns(df_2018_d7)
df_2019_d7 = remove_margin_of_error_columns(df_2019_d7)
df_2020_d7 = remove_margin_of_error_columns(df_2020_d7)
df_2021_d7 = remove_margin_of_error_columns(df_2021_d7)
df_2022_d7 = remove_margin_of_error_columns(df_2022_d7)

# %%
df_2011_d7 = rename_columns(df_2011_d7)
df_2012_d7 = rename_columns(df_2012_d7)
df_2013_d7 = rename_columns(df_2013_d7)
df_2014_d7 = rename_columns(df_2014_d7)
df_2015_d7 = rename_columns(df_2015_d7)
df_2016_d7 = rename_columns(df_2016_d7)
df_2017_d7 = rename_columns(df_2017_d7)
df_2018_d7 = rename_columns(df_2018_d7)
df_2019_d7 = rename_columns(df_2019_d7)
df_2020_d7 = rename_columns(df_2020_d7)
df_2021_d7 = rename_columns(df_2021_d7)
df_2022_d7 = rename_columns(df_2022_d7)

# %%
def remove_grapi_columns(df):
    columns_to_drop = df.filter(like='GRAPI').columns
    columns_to_drop2 = df.filter(like='NaN').columns
    columns_to_drop3 = df.filter(like='rate').columns
    df = df.drop(columns=columns_to_drop)
    df = df.drop(columns=columns_to_drop2)
    df = df.drop(columns=columns_to_drop3)
    return df

# Apply to each dataframe individually
df_2011 = remove_grapi_columns(df_2011)
df_2012 = remove_grapi_columns(df_2012)
df_2013 = remove_grapi_columns(df_2013)
df_2014 = remove_grapi_columns(df_2014)
df_2015 = remove_grapi_columns(df_2015)
df_2016 = remove_grapi_columns(df_2016)
df_2017 = remove_grapi_columns(df_2017)
df_2018 = remove_grapi_columns(df_2018)
df_2019 = remove_grapi_columns(df_2019)
df_2020 = remove_grapi_columns(df_2020)
df_2021 = remove_grapi_columns(df_2021)
df_2022 = remove_grapi_columns(df_2022)

# Apply to each _d7 dataframe
df_2011_d7 = remove_grapi_columns(df_2011_d7)
df_2012_d7 = remove_grapi_columns(df_2012_d7)
df_2013_d7 = remove_grapi_columns(df_2013_d7)
df_2014_d7 = remove_grapi_columns(df_2014_d7)
df_2015_d7 = remove_grapi_columns(df_2015_d7)
df_2016_d7 = remove_grapi_columns(df_2016_d7)
df_2017_d7 = remove_grapi_columns(df_2017_d7)
df_2018_d7 = remove_grapi_columns(df_2018_d7)
df_2019_d7 = remove_grapi_columns(df_2019_d7)
df_2020_d7 = remove_grapi_columns(df_2020_d7)
df_2021_d7 = remove_grapi_columns(df_2021_d7)
df_2022_d7 = remove_grapi_columns(df_2022_d7)

# %%
df_2011_d7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Columns: 134 entries, Geography to nan
# dtypes: float64(1), object(133)
# memory usage: 31.5+ KB

# %%
df_2011_d7
# Out:
# 0              Geography                               Geographic Area Name  \
# 0   1400000US25025010300    Census Tract 103, Suffolk County, Massachusetts
# 1   1400000US25025010403  Census Tract 104.03, Suffolk County, Massachus...
# 2   1400000US25025010404  Census Tract 104.04, Suffolk County, Massachus...
# 3   1400000US25025010405  Census Tract 104.05, Suffolk County, Massachus...
# 4   1400000US25025010500    Census Tract 105, Suffolk County, Massachusetts
# 5   1400000US25025010600    Census Tract 106, Suffolk County, Massachusetts
# 6   1400000US25025010701  Census Tract 107.01, Suffolk County, Massachus...
# 7   1400000US25025070600    Census Tract 706, Suffolk County, Massachusetts
# 8   1400000US25025070700    Census Tract 707, Suffolk County, Massachusetts
# 9   1400000US25025071101  Census Tract 711.01, Suffolk County, Massachus...
# 10  1400000US25025080100    Census Tract 801, Suffolk County, Massachusetts
# ...

# %% [markdown]
# #### Removing columns that we are not concerned with, aggregating the dataframes such that there is 1 single aggregated row for each year with the total / median information

# %%
import pandas as pd
import numpy as np

def convert_columns_to_numeric(df):
    return df.apply(pd.to_numeric, errors='coerce')

def remove_specific_columns(df):
    columns_to_drop = df.filter(regex='Geograph|PERCENT|Margin of Error|Percent|Moved In|Moved in|SELECTED MONTHLY OWNER COSTS|YEAR STRUCTURE BUILT|VEHICLES AVAILABLE|HOUSE HEATING FUEL|YEAR HOUSEHOLDER MOVED INTO UNIT|complete plumbing facilities|MORTGAGE STATUS|OCCUPANTS PER ROOM|kitchen').columns
    columns_to_keep = [col for col in df.columns if col not in columns_to_drop]
    if len(columns_to_keep) == 0:
        print("Warning: All columns would be dropped. Keeping all columns instead.")
        return df
    return df[columns_to_keep]

def aggregate_rows(df):
    # Identify median columns
    median_columns = df.filter(regex='Median').columns
    
    # Aggregate non-median columns by sum
    sum_df = df.drop(columns=median_columns).sum().to_frame().T
    
    # Aggregate median columns by mean
    median_df = df[median_columns].mean().to_frame().T
    
    # Combine the results
    return pd.concat([sum_df, median_df], axis=1)

def process_dataframe(df):
    df = convert_columns_to_numeric(df)
    df = remove_specific_columns(df)
    df = aggregate_rows(df)
    return df

# Apply the process_dataframe function to each dataframe manually
df_2011_d7 = process_dataframe(df_2011_d7)
df_2012_d7 = process_dataframe(df_2012_d7)
df_2013_d7 = process_dataframe(df_2013_d7)
df_2014_d7 = process_dataframe(df_2014_d7)
df_2015_d7 = process_dataframe(df_2015_d7)
df_2016_d7 = process_dataframe(df_2016_d7)
df_2017_d7 = process_dataframe(df_2017_d7)
df_2018_d7 = process_dataframe(df_2018_d7)
df_2019_d7 = process_dataframe(df_2019_d7)
df_2020_d7 = process_dataframe(df_2020_d7)
df_2021_d7 = process_dataframe(df_2021_d7)
df_2022_d7 = process_dataframe(df_2022_d7)

# %%
df_2011_d7.columns
# Out:
# Index([                                                     'Total Housing Units',
#                                                             'Total Housing Units',
#                                                          'Occupied Housing Units',
#                                                            'Vacant Housing Units',
#                                                             'Total Housing Units',
#                                                             'Total Housing Units',
#                                                                '1-unit, detached',
#                                                                '1-unit, attached',
#                                                                         '2 units',
#                                                                       '3-4 units',
#                                                                       '5-9 units',
# ...

# %%
'''df_2011_d7.insert(0, 'Year', 2011)
df_2012_d7.insert(0, 'Year', 2012)
df_2013_d7.insert(0, 'Year', 2013)
df_2014_d7.insert(0, 'Year', 2014)
df_2015_d7.insert(0, 'Year', 2015)
df_2016_d7.insert(0, 'Year', 2016)
df_2017_d7.insert(0, 'Year', 2017)
df_2018_d7.insert(0, 'Year', 2018)
df_2019_d7.insert(0, 'Year', 2019)
df_2020_d7.insert(0, 'Year', 2020)
df_2021_d7.insert(0, 'Year', 2021)
df_2022_d7.insert(0, 'Year', 2022)'''
# Out:
# "df_2011_d7.insert(0, 'Year', 2011)\ndf_2012_d7.insert(0, 'Year', 2012)\ndf_2013_d7.insert(0, 'Year', 2013)\ndf_2014_d7.insert(0, 'Year', 2014)\ndf_2015_d7.insert(0, 'Year', 2015)\ndf_2016_d7.insert(0, 'Year', 2016)\ndf_2017_d7.insert(0, 'Year', 2017)\ndf_2018_d7.insert(0, 'Year', 2018)\ndf_2019_d7.insert(0, 'Year', 2019)\ndf_2020_d7.insert(0, 'Year', 2020)\ndf_2021_d7.insert(0, 'Year', 2021)\ndf_2022_d7.insert(0, 'Year', 2022)"

# %%
rent_columns = df_2021_d7.filter(like='Estimate', axis=1)
print(rent_columns.columns)
# Out:
# Index(['Estimate!!ROOMS!!Total housing units',
#        'Estimate!!BEDROOMS!!Total housing units',
#        'Estimate!!HOUSING TENURE!!Occupied housing units',
#        'Estimate!!SELECTED CHARACTERISTICS!!Occupied housing units',
#        'Estimate!!SELECTED CHARACTERISTICS!!Occupied housing units!!No telephone service available',
#        'Estimate!!VALUE!!Owner-occupied units'],
#       dtype='object', name=0)

# %%
df_2021_d7.columns
# Out:
# Index([                                                                       'Total Housing Units',
#                                                                               'Total Housing Units',
#                                                                            'Occupied Housing Units',
#                                                                              'Vacant Housing Units',
#                                                                               'Total Housing Units',
#                                                                               'Total Housing Units',
#                                                                                  '1-unit, detached',
#                                                                                  '1-unit, attached',
#                                                                                           '2 units',
# ...

# %%
df_2021_d7['Median Rent($)']
# Out:
# 0    1533.75
# Name: Median Rent($), dtype: float64

# %%
df_2021['Median Rent($)']
# Out:
# 0    1783
# Name: Median Rent($), dtype: object

# %%
df_2011_d7['Median Rent($)']
# Out:
# 0    1049.607143
# Name: Median Rent($), dtype: float64

# %%
df_2011['Median Rent($)']
# Out:
# 0    1238
# Name: Median Rent($), dtype: object

# %% [markdown]
# ### Comparing Median Rent for District 7 vs. Boston

# %%
import matplotlib.pyplot as plt
import pandas as pd

for year in range(2011, 2023):
    df = globals()[f'df_{year}']
    df['Median Rent($)'] = pd.to_numeric(df['Median Rent($)'], errors='coerce')

# Create a list of years
years = range(2011, 2023)

# Create lists to store the median rent values
d7_median_rents = []
boston_median_rents = []

# Extract median rent values from each dataframe
for year in years:
    d7_df = globals()[f'df_{year}_d7']
    boston_df = globals()[f'df_{year}']
    
    d7_median_rents.append(d7_df['Median Rent($)'].values[0])
    boston_median_rents.append(boston_df['Median Rent($)'].values[0])

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(years, d7_median_rents, marker='o', label='District 7')
plt.plot(years, boston_median_rents, marker='s', label='Boston')

plt.title('Median Rent Comparison: District 7 vs Boston (2011-2022)')
plt.xlabel('Year')
plt.ylabel('Median Rent ($)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Add value labels
for i, (d7_rent, boston_rent) in enumerate(zip(d7_median_rents, boston_median_rents)):
    plt.text(years[i], d7_rent, f'${d7_rent:,.0f}', ha='left', va='bottom')
    plt.text(years[i], boston_rent, f'${boston_rent:,.0f}', ha='right', va='top')

plt.tight_layout()
plt.show()

# %%
for year in range(2011, 2023):
    df = globals()[f'df_{year}']
    df['Median Rent($)'] = pd.to_numeric(df['Median Rent($)'], errors='coerce')

for year in range(2011, 2023):
    df = globals()[f'df_{year}']
    print(f"{year} Median Rent: ${df['Median Rent($)'].values[0]:,.0f}")
# Out:
# 2011 Median Rent: $1,238
# 2012 Median Rent: $1,265
# 2013 Median Rent: $1,281
# 2014 Median Rent: $1,298
# 2015 Median Rent: $1,320
# 2016 Median Rent: $1,369
# 2017 Median Rent: $1,445
# 2018 Median Rent: $1,539
# 2019 Median Rent: $1,620
# 2020 Median Rent: $1,685
# 2021 Median Rent: $1,783
# 2022 Median Rent: $1,981
