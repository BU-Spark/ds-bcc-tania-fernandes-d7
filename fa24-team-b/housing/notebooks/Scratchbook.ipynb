# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/rentsmart.csv")

# %%
#remove missing data

df = df.dropna()

#remove 00:00:00 behind date
df['date'] = pd.to_datetime(df['date'], errors='coerce', format='mixed')
df['date'] = df['date'].dt.date

#fliter zip codes and add 0 in front
d7_zip_codes = ["02119", "02120", "02121", "02122", "02124", "02125", "02115", "02215", "02118"]
df['zip_code'] = df['zip_code'].apply(lambda x: str(x).zfill(5))
df = df[df['zip_code'].isin(d7_zip_codes)]

#fliter neighborhoods
d7_neighborhood = ["Dorchester", "Fenway", "Roxbury", "South End"]
df = df[df['neighborhood'].isin(d7_neighborhood)].copy()

#remove .0 behind year_built and year_remodeled
df['year_remodeled'] = df['year_remodeled'].astype(int)
df['year_built'] = df['year_built'].astype(int)

#group very similar descriptions
replace_dict = {
    "Work w/out Permit": "Work Without Permit",
    "Work without permit": "Work Without Permit",
    "Working Without a Permit": "Work Without Permit",
    "Working Without Electrical Permit": "Work Without Permit", 
    "Unsafe Strcuture": "Unsafe Structures"
}

df['description'] = df['description'].replace(replace_dict)

df
# Out:
#              date          violation_type                       description  \
# 0      2024-10-02  Enforcement Violations       Improper storage trash: res
# 1      2024-10-02  Enforcement Violations       Improper storage trash: res
# 2      2024-10-02  Enforcement Violations    Overfilling of barrel/dumpster
# 3      2024-10-01  Enforcement Violations       Overgrown Weeds On Property
# 4      2024-10-01  Enforcement Violations      illegal parking prop owner 1
# ...           ...                     ...                               ...
# 64094  2019-10-29      Housing Complaints  Unsatisfactory Living Conditions
# 64095  2019-10-29      Housing Complaints                          Plumbing
# 64096  2019-10-29      Housing Complaints  Unsatisfactory Living Conditions
# 64097  2019-10-29      Housing Complaints   Rental Unit Delivery Conditions
# 64098  2019-10-29     Sanitation Requests                   Rodent Activity
#
#                                address neighborhood zip_code      parcel  \
# 0      1081-1083 Dorchester Ave, 02125   Dorchester    02125  1302139000
# 1                   6 Dawes Ter, 02125   Dorchester    02125   703977000
# 2              7 Bakersfield St, 02125   Dorchester    02125  1301796000
# 3                27 Woodbine St, 02119      Roxbury    02119  1200848000
# 4                2 Humboldt Ave, 02119      Roxbury    02119  1201598250
# ...                                ...          ...      ...         ...
# 64094           45 Dwight St #A, 02118      Roxbury    02118   305741000
# 64095            610 Tremont St, 02118      Roxbury    02118   900091000
# 64096         56 Bowdoin Ave #4, 02121   Dorchester    02121  1401292000
# 64097           5 S Charlame Ct, 02119      Roxbury    02119  1201125000
# 64098              131 Devon St, 02121   Dorchester    02121  1400623000
#
#                                 owner  year_built  year_remodeled  \
# 0      DORCHESTER FIRST REALTY  TRUST        1905            2014
# 1                     MADEK CHARLES V        1905            1970
# 2                  CESCO LLC MASS LLC        1936            1981
# 3                 WHITE GILBERT G III        1890            2010
# 4            TWO HUMBOLDT AV CONDO TR        1999            1999
# ...                               ...         ...             ...
# 64094   HISTORIC SOUTH END LP MASS LP        1900            1990
# 64095          PHIL C BRADLEY HOUSING        1920            1998
# 64096                  ALLEN MARY ANN        1950            2004
# 64097      CHARLAME PARK HOMES I COOP        1964            1990
# 64098         PROJECT 77 LLC MASS LLC        1910            2015
#
#                      property_type   latitude  longitude  year
# 0             Residential 3-family  42.313779 -71.057314  2024
# 1             Residential 3-family  42.318930 -71.060761  2024
# 2      Residential 7 or more units  42.317846 -71.060866  2024
# 3             Residential 1-family  42.318880 -71.079861  2024
# 4                Condominium Main*  42.320570 -71.085741  2024
# ...                            ...        ...        ...   ...
# 64094  Residential 7 or more units  42.344531 -71.069138  2019
# 64095   Mixed Use (Res. and Comm.)  42.342540 -71.073708  2019
# 64096  Residential 7 or more units  42.301370 -71.074491  2019
# 64097  Residential 7 or more units  42.319490 -71.085619  2019
# 64098         Residential 3-family  42.307740 -71.076701  2019
#
# [64099 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64099 entries, 0 to 64098
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            64099 non-null  object
#  1   violation_type  64099 non-null  object
#  2   description     64099 non-null  object
#  3   address         64099 non-null  object
#  4   neighborhood    64099 non-null  object
#  5   zip_code        64099 non-null  object
#  6   parcel          64099 non-null  int64
#  7   owner           64099 non-null  object
#  8   year_built      64099 non-null  int64
#  9   year_remodeled  64099 non-null  int64
#  10  property_type   64099 non-null  object
#  11  latitude        64099 non-null  float64
#  12  longitude       64099 non-null  float64
#  13  year            64099 non-null  int64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 6.8+ MB

# %%
print(df["year"].unique())
print(df["neighborhood"].unique())
print(df["zip_code"].unique())
# Out:
# [2024 2023 2022 2021 2020 2019]
# ['Dorchester' 'Roxbury']
# ['02125' '02119' '02118' '02124' '02121' '02122']

# %%
df["year"] = df["year"].astype(str)
df["year_built"] = df["year_built"].astype(str)
df["year_remodeled"] = df["year_remodeled"].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64099 entries, 0 to 64098
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            64099 non-null  object
#  1   violation_type  64099 non-null  object
#  2   description     64099 non-null  object
#  3   address         64099 non-null  object
#  4   neighborhood    64099 non-null  object
#  5   zip_code        64099 non-null  int64
#  6   parcel          64099 non-null  int64
#  7   owner           64099 non-null  object
#  8   year_built      64099 non-null  object
#  9   year_remodeled  64099 non-null  object
#  10  property_type   64099 non-null  object
#  11  latitude        64099 non-null  float64
#  12  longitude       64099 non-null  float64
#  13  year            64099 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 6.8+ MB

# %%
# Convert non-string columns to strings temporarily
# Replace line breaks within each string with a space
df['description'] = df['description'].str.replace('\n', '', regex=True)
df.to_csv("../data/rentsmart.csv", index=False, quotechar='"', quoting=csv.QUOTE_NONNUMERIC)

# %%
df_all = pd.read_csv("../data/rentsmart_2019_present.csv")

# %%
#remove missing data

df_all = df_all.dropna()

#remove 00:00:00 behind date
df_all['date'] = pd.to_datetime(df_all['date'], errors='coerce', format='mixed')
df_all['year'] = df_all['date'].dt.year
df_all['date'] = df_all['date'].dt.date

#fliter zip codes and add 0 in front
d7_zip_codes = ["02119", "02120", "02121", "02122", "02124", "02125", "02115", "02215", "02118"]
df_all['zip_code'] = df_all['zip_code'].apply(lambda x: str(x).zfill(5))
df_all = df_all[df_all['zip_code'].isin(d7_zip_codes)]

#fliter neighborhoods
d7_neighborhood = ["Dorchester", "Fenway", "Roxbury", "South End"]
df_all = df_all[df_all['neighborhood'].isin(d7_neighborhood)].copy()

#remove .0 behind year_built and year_remodeled
df_all['year_remodeled'] = df_all['year_remodeled'].astype(int)
df_all['year_built'] = df_all['year_built'].astype(int)

#group very similar descriptions
replace_dict = {
    "Work w/out Permit": "Work Without Permit",
    "Work without permit": "Work Without Permit",
    "Working Without a Permit": "Work Without Permit",
    "Working Without Electrical Permit": "Work Without Permit", 
    "Unsafe Strcuture": "Unsafe Structures"
}

df_all['description'] = df_all['description'].replace(replace_dict)

df_all
# Out:
#            _id        date          violation_type  \
# 5            6  2024-11-10     Sanitation Requests
# 13          14  2024-11-10      Housing Complaints
# 18          19  2024-11-10      Housing Complaints
# 22          23  2024-11-10      Housing Complaints
# 32          33  2024-11-10  Enforcement Violations
# ...        ...         ...                     ...
# 344235  344236  2019-12-09  Enforcement Violations
# 344251  344252  2019-12-09  Enforcement Violations
# 344265  344266  2019-12-09  Enforcement Violations
# 344293  344294  2019-12-08      Housing Complaints
# 344296  344297  2019-12-08     Sanitation Requests
#
#                                             description  \
# 5                                       Rodent Activity
# 13      Unsatisfactory Utilities - Electrical, Plumbing
# 18                                  Work Without Permit
# 22                                  Work Without Permit
# 32                          Improper storage trash: res
# ...                                                 ...
# 344235                      Improper storage trash: res
# 344251                      Improper storage trash: res
# 344265                      Improper storage trash: res
# 344293                   Heat - Excessive, Insufficient
# 344296                               Abandoned Vehicles
#
#                                     address neighborhood zip_code      parcel  \
# 5                      36 Ashland St, 02122   Dorchester    02122  1600202000
# 13                200 Hancock St #11, 02125   Dorchester    02125  1301625000
# 18                      19 Hanson St, 02118      Roxbury    02118   305840000
# 22               11 E Springfield St, 02118      Roxbury    02118   801556000
# 32                      103 Cedar St, 02119      Roxbury    02119  1100107000
# ...                                     ...          ...      ...         ...
# 344235  491 Massachusetts Ave #A-491, 02118      Roxbury    02118   900982010
# 344251             215-217 Quincy St, 02121   Dorchester    02121  1400150000
# 344265                  23 Dunlap St, 02124   Dorchester    02124  1700500000
# 344293             10 Hartwell St #2, 02121   Dorchester    02121  1202517000
# 344296        1085 Dorchester Ave #1, 02125   Dorchester    02125  1302140000
#
#                             owner  year_built  year_remodeled  \
# 5                       NGUYEN VU        1965            2012
# 13             AU 200 HANCOCK LLC        1968            1980
# 18                    BABKA SCOTT        1890            2018
# 22            OBRIEN PATRICK J TS        1899            1988
# 32          DAVIS JENNIFER E ETAL        1900            1981
# ...                           ...         ...             ...
# 344235  FAYE-SEARS CONDOMINIUM TR        1999            1999
# 344251               ALICEA ANGEL        1905            1996
# 344265             ELHALWANI ISAM        1900            2006
# 344293           K&K REALTY TRUST        1900            1988
# 344296       CITY WALK REALTY LLC        1905            2011
#
#                        property_type   latitude  longitude  year
# 5               Residential 1-family  42.299950 -71.051531  2024
# 13       Residential 7 or more units  42.310540 -71.061151  2024
# 18              Residential 1-family  42.343890 -71.070251  2024
# 22      Residential 4 or more family  42.336470 -71.075981  2024
# 32              Residential 2-family  42.327120 -71.093251  2024
# ...                              ...        ...        ...   ...
# 344235             Condominium Main*  42.339306 -71.080757  2019
# 344251          Residential 2-family  42.312400 -71.074281  2019
# 344265          Residential 3-family  42.292950 -71.073281  2019
# 344293   Residential 7 or more units  42.309324 -71.083943  2019
# 344296          Residential 3-family  42.313670 -71.057281  2019
#
# [64749 rows x 15 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64749 entries, 5 to 344296
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   _id             64749 non-null  int64
#  1   date            64749 non-null  object
#  2   violation_type  64749 non-null  object
#  3   description     64749 non-null  object
#  4   address         64749 non-null  object
#  5   neighborhood    64749 non-null  object
#  6   zip_code        64749 non-null  object
#  7   parcel          64749 non-null  int64
#  8   owner           64749 non-null  object
#  9   year_built      64749 non-null  int64
#  10  year_remodeled  64749 non-null  int64
#  11  property_type   64749 non-null  object
#  12  latitude        64749 non-null  float64
#  13  longitude       64749 non-null  float64
#  14  year            64749 non-null  int32
# dtypes: float64(2), int32(1), int64(4), object(8)
# memory usage: 7.7+ MB

# %%
print(df_all["year"].unique())
print(df_all["neighborhood"].unique())
print(df_all["zip_code"].unique())
print(df_all["violation_type"].unique())
# Out:
# [2024 2023 2022 2021 2020 2019]
# ['Dorchester' 'Roxbury']
# ['02122' '02125' '02118' '02119' '02121' '02124']
# ['Sanitation Requests' 'Housing Complaints' 'Enforcement Violations'
#  'Housing Violations' 'Building Violations' 'Civic Maintenance Requests']

# %%
df_all['description'] = df_all['description'].str.replace('\n', '', regex=True)
df_all.to_csv("../data/rentsmart_2019_present.csv", index=False, quotechar='"', quoting=csv.QUOTE_NONNUMERIC)

# %%
print(df_all['zip_code'].dtype)
# Out:
# object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64099 entries, 0 to 64098
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            64099 non-null  object
#  1   violation_type  64099 non-null  object
#  2   description     64099 non-null  object
#  3   address         64099 non-null  object
#  4   neighborhood    64099 non-null  object
#  5   zip_code        64099 non-null  object
#  6   parcel          64099 non-null  int64
#  7   owner           64099 non-null  object
#  8   year_built      64099 non-null  int64
#  9   year_remodeled  64099 non-null  int64
#  10  property_type   64099 non-null  object
#  11  latitude        64099 non-null  float64
#  12  longitude       64099 non-null  float64
#  13  year            64099 non-null  int64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 6.8+ MB
